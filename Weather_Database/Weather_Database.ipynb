# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import geoviews as gv
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 747

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
            
            
        # Append the city information into the city_data list
        city_data.append({"City": city,
                          "Country": country,
                          "Lat": lat,
                          "Lng": lng,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Current Description": description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taulaga
# Processing Record 2 of Set 1 | edinburgh of the seven seas
# Processing Record 3 of Set 1 | uturoa
# Processing Record 4 of Set 1 | isafjordur
# Processing Record 5 of Set 1 | quellon
# Processing Record 6 of Set 1 | smithers
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | forster
# Processing Record 9 of Set 1 | adamstown
# Processing Record 10 of Set 1 | sursk
# Processing Record 11 of Set 1 | whitehorse
# Processing Record 12 of Set 1 | somerset east
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | quarai
# Processing Record 15 of Set 1 | mount pearl
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | papatowai
# Processing Record 20 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 21 of Set 1 | vodnyy
# Processing Record 22 of Set 1 | saipan
# Processing Record 23 of Set 1 | sitka
# Processing Record 24 of Set 1 | olonkinbyen
# Processing Record 25 of Set 1 | laojunmiao
# Processing Record 26 of Set 1 | arkhangel'sk
# Processing Record 27 of Set 1 | labytnangi
# Processing Record 28 of Set 1 | port mathurin
# Processing Record 29 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 30 of Set 1 | port-aux-francais
# Processing Record 31 of Set 1 | carloforte
# Processing Record 32 of Set 1 | margaret river
# Processing Record 33 of Set 1 | touros
# Processing Record 34 of Set 1 | mersin
# Processing Record 35 of Set 1 | laguna
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | waitangi
# Processing Record 38 of Set 1 | cockburn town
# Processing Record 39 of Set 1 | nabire
# Processing Record 40 of Set 1 | usogorsk
# Processing Record 41 of Set 1 | udachny
# Processing Record 42 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 43 of Set 1 | g'uzor
# Processing Record 44 of Set 1 | shimoda
# Processing Record 45 of Set 1 | labrador city
# Processing Record 46 of Set 1 | puerto natales
# Processing Record 47 of Set 1 | kingston
# Processing Record 48 of Set 1 | pangody
# Processing Record 49 of Set 1 | kimbe
# Processing Record 50 of Set 1 | greymouth
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | yarkovo
# Processing Record 3 of Set 2 | blackmans bay
# Processing Record 4 of Set 2 | nikolayevsk-on-amure
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | aasiaat
# Processing Record 7 of Set 2 | la ronge
# Processing Record 8 of Set 2 | bikenibeu village
# Processing Record 9 of Set 2 | afaahiti
# Processing Record 10 of Set 2 | grytviken
# Processing Record 11 of Set 2 | wailua homesteads
# Processing Record 12 of Set 2 | muikamachi
# Processing Record 13 of Set 2 | verkhnevilyuysk
# Processing Record 14 of Set 2 | qaqortoq
# Processing Record 15 of Set 2 | badger
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | west island
# Processing Record 18 of Set 2 | kilju
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | ta'izz
# Processing Record 22 of Set 2 | grantsville
# Processing Record 23 of Set 2 | pisco
# Processing Record 24 of Set 2 | sougueur
# Processing Record 25 of Set 2 | walvis bay
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | minas de marcona
# Processing Record 28 of Set 2 | vilyuchinsk
# Processing Record 29 of Set 2 | gornozavodsk
# Processing Record 30 of Set 2 | robore
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | mirnyy
# Processing Record 33 of Set 2 | enewetak
# Processing Record 34 of Set 2 | axim
# Processing Record 35 of Set 2 | anadyr
# Processing Record 36 of Set 2 | acapulco de juarez
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | anshun
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | ar ruways
# Processing Record 42 of Set 2 | ancud
# Processing Record 43 of Set 2 | belo sur tsiribihina
# Processing Record 44 of Set 2 | palangkaraya
# Processing Record 45 of Set 2 | kampong thom
# Processing Record 46 of Set 2 | saratamata
# City not found. Skipping...
# Processing Record 47 of Set 2 | ust-nera
# Processing Record 48 of Set 2 | hawaiian paradise park
# Processing Record 49 of Set 2 | bilibino
# Processing Record 50 of Set 2 | sisimiut
# Processing Record 1 of Set 3 | taroa
# Processing Record 2 of Set 3 | iqaluit
# Processing Record 3 of Set 3 | tadine
# Processing Record 4 of Set 3 | constantia
# Processing Record 5 of Set 3 | egilsstadir
# Processing Record 6 of Set 3 | tual
# Processing Record 7 of Set 3 | daru
# Processing Record 8 of Set 3 | shevchenko
# Processing Record 9 of Set 3 | umm kaddadah
# Processing Record 10 of Set 3 | corner brook
# Processing Record 11 of Set 3 | atafu village
# Processing Record 12 of Set 3 | kapa'a
# Processing Record 13 of Set 3 | weno
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | lake havasu city
# Processing Record 16 of Set 3 | ramapuram
# Processing Record 17 of Set 3 | pariaman
# Processing Record 18 of Set 3 | iskateley
# Processing Record 19 of Set 3 | berwick-upon-tweed
# Processing Record 20 of Set 3 | hasaki
# Processing Record 21 of Set 3 | la palma
# Processing Record 22 of Set 3 | falun
# Processing Record 23 of Set 3 | namanga
# Processing Record 24 of Set 3 | jamestown
# Processing Record 25 of Set 3 | klyuchi
# Processing Record 26 of Set 3 | pavlovsk
# Processing Record 27 of Set 3 | port blair
# Processing Record 28 of Set 3 | es castell
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | guerrero negro
# Processing Record 31 of Set 3 | kollam
# Processing Record 32 of Set 3 | okhotsk
# Processing Record 33 of Set 3 | happy valley-goose bay
# Processing Record 34 of Set 3 | skhira
# Processing Record 35 of Set 3 | invercargill
# Processing Record 36 of Set 3 | selebi-phikwe
# Processing Record 37 of Set 3 | antsiranana
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | znamenka
# Processing Record 40 of Set 3 | revda
# Processing Record 41 of Set 3 | haiku-pauwela
# Processing Record 42 of Set 3 | tucuma
# Processing Record 43 of Set 3 | kidal
# Processing Record 44 of Set 3 | fundacion
# Processing Record 45 of Set 3 | uliastay
# Processing Record 46 of Set 3 | santa teresa del tuy
# Processing Record 47 of Set 3 | tura
# Processing Record 48 of Set 3 | longyearbyen
# Processing Record 49 of Set 3 | stanley
# Processing Record 50 of Set 3 | vila franca do campo
# Processing Record 1 of Set 4 | aykhal
# Processing Record 2 of Set 4 | isla mujeres
# Processing Record 3 of Set 4 | kegeyli shahar
# Processing Record 4 of Set 4 | nadym
# Processing Record 5 of Set 4 | wolow
# Processing Record 6 of Set 4 | carutapera
# Processing Record 7 of Set 4 | prokop'yevsk
# Processing Record 8 of Set 4 | zeerust
# Processing Record 9 of Set 4 | nar'yan-mar
# Processing Record 10 of Set 4 | saffle
# City not found. Skipping...
# Processing Record 11 of Set 4 | aripuana
# Processing Record 12 of Set 4 | tarija
# Processing Record 13 of Set 4 | cosala
# Processing Record 14 of Set 4 | portoferraio
# Processing Record 15 of Set 4 | rio grande
# Processing Record 16 of Set 4 | portland
# Processing Record 17 of Set 4 | kerikeri
# Processing Record 18 of Set 4 | minas de matahambre
# City not found. Skipping...
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | mount gambier
# Processing Record 22 of Set 4 | merizo village
# Processing Record 23 of Set 4 | dwarka
# Processing Record 24 of Set 4 | fisterra
# Processing Record 25 of Set 4 | ouani
# Processing Record 26 of Set 4 | machico
# Processing Record 27 of Set 4 | manismata
# Processing Record 28 of Set 4 | sohlde
# Processing Record 29 of Set 4 | tazovsky
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | st. john's
# Processing Record 32 of Set 4 | kodoli
# Processing Record 33 of Set 4 | college
# Processing Record 34 of Set 4 | crane
# Processing Record 35 of Set 4 | faya-largeau
# Processing Record 36 of Set 4 | progreso
# Processing Record 37 of Set 4 | lebu
# Processing Record 38 of Set 4 | nizhneangarsk
# Processing Record 39 of Set 4 | caleta de carquin
# Processing Record 40 of Set 4 | teluknaga
# Processing Record 41 of Set 4 | dazuocun
# Processing Record 42 of Set 4 | hermanus
# Processing Record 43 of Set 4 | lorengau
# Processing Record 44 of Set 4 | totness
# Processing Record 45 of Set 4 | susuman
# Processing Record 46 of Set 4 | san patricio
# Processing Record 47 of Set 4 | yermakovskoye
# Processing Record 48 of Set 4 | sonqor
# Processing Record 49 of Set 4 | choibalsan
# Processing Record 50 of Set 4 | erenhot
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 2 of Set 5 | yangor
# City not found. Skipping...
# Processing Record 3 of Set 5 | barra do bugres
# Processing Record 4 of Set 5 | nouadhibou
# Processing Record 5 of Set 5 | tolanaro
# Processing Record 6 of Set 5 | alice springs
# Processing Record 7 of Set 5 | olivenza
# Processing Record 8 of Set 5 | dunedin
# Processing Record 9 of Set 5 | la sarre
# Processing Record 10 of Set 5 | talnakh
# Processing Record 11 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 12 of Set 5 | parksville
# Processing Record 13 of Set 5 | maun
# Processing Record 14 of Set 5 | gaigeturi
# Processing Record 15 of Set 5 | port lincoln
# Processing Record 16 of Set 5 | ixtapa
# Processing Record 17 of Set 5 | kolondieba
# Processing Record 18 of Set 5 | fale old settlement
# Processing Record 19 of Set 5 | mitu
# Processing Record 20 of Set 5 | havre
# Processing Record 21 of Set 5 | new prague
# Processing Record 22 of Set 5 | fuerte olimpo
# Processing Record 23 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 5 | zuni pueblo
# Processing Record 25 of Set 5 | lubang
# Processing Record 26 of Set 5 | newman
# Processing Record 27 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | masterton
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | trujillo
# Processing Record 32 of Set 5 | kegen
# Processing Record 33 of Set 5 | la passe
# Processing Record 34 of Set 5 | laurentides
# Processing Record 35 of Set 5 | basoko
# Processing Record 36 of Set 5 | utrik
# Processing Record 37 of Set 5 | krasnyy oktyabr'
# Processing Record 38 of Set 5 | san jose
# Processing Record 39 of Set 5 | lichinga
# Processing Record 40 of Set 5 | mersa matruh
# Processing Record 41 of Set 5 | richards bay
# Processing Record 42 of Set 5 | sinop
# Processing Record 43 of Set 5 | kirakira
# Processing Record 44 of Set 5 | lovington
# Processing Record 45 of Set 5 | kodiak
# Processing Record 46 of Set 5 | olinda
# Processing Record 47 of Set 5 | codrington
# Processing Record 48 of Set 5 | abra pampa
# Processing Record 49 of Set 5 | hepo
# Processing Record 50 of Set 5 | pangoa
# Processing Record 1 of Set 6 | as sulayyil
# Processing Record 2 of Set 6 | sorong
# Processing Record 3 of Set 6 | campo verde
# Processing Record 4 of Set 6 | ghadamis
# Processing Record 5 of Set 6 | kattivakkam
# Processing Record 6 of Set 6 | ketchikan
# Processing Record 7 of Set 6 | lhasa
# Processing Record 8 of Set 6 | brookings
# Processing Record 9 of Set 6 | gladstone
# Processing Record 10 of Set 6 | banda aceh
# Processing Record 11 of Set 6 | tobelo
# Processing Record 12 of Set 6 | dryden
# Processing Record 13 of Set 6 | kolpashevo
# Processing Record 14 of Set 6 | agde
# Processing Record 15 of Set 6 | vorkuta
# Processing Record 16 of Set 6 | conception bay south
# Processing Record 17 of Set 6 | moanda
# Processing Record 18 of Set 6 | kostomuksha
# Processing Record 19 of Set 6 | villa de soto
# Processing Record 20 of Set 6 | huayin
# Processing Record 21 of Set 6 | bangjun
# Processing Record 22 of Set 6 | ts'alenjikha
# Processing Record 23 of Set 6 | tobruk
# Processing Record 24 of Set 6 | phalaborwa
# Processing Record 25 of Set 6 | soufriere
# Processing Record 26 of Set 6 | santa marinella
# Processing Record 27 of Set 6 | chibougamau
# Processing Record 28 of Set 6 | dalai
# Processing Record 29 of Set 6 | prince rupert
# Processing Record 30 of Set 6 | likisa
# Processing Record 31 of Set 6 | tralee
# Processing Record 32 of Set 6 | changyon
# Processing Record 33 of Set 6 | broken hill
# Processing Record 34 of Set 6 | chifeng
# Processing Record 35 of Set 6 | gostynin
# Processing Record 36 of Set 6 | lompoc
# Processing Record 37 of Set 6 | bargara
# City not found. Skipping...
# Processing Record 38 of Set 6 | strathmore
# Processing Record 39 of Set 6 | colac
# Processing Record 40 of Set 6 | sao felix do xingu
# Processing Record 41 of Set 6 | auki
# Processing Record 42 of Set 6 | champerico
# Processing Record 43 of Set 6 | taco pozo
# Processing Record 44 of Set 6 | luau
# Processing Record 45 of Set 6 | narail
# Processing Record 46 of Set 6 | lodwar
# Processing Record 47 of Set 6 | fortuna
# Processing Record 48 of Set 6 | midvagur
# Processing Record 49 of Set 6 | port douglas
# Processing Record 50 of Set 6 | ismailia
# Processing Record 1 of Set 7 | greenville
# Processing Record 2 of Set 7 | gafargaon
# Processing Record 3 of Set 7 | al wakrah
# Processing Record 4 of Set 7 | klaksvik
# Processing Record 5 of Set 7 | sasovo
# Processing Record 6 of Set 7 | tyuratam
# Processing Record 7 of Set 7 | yugorsk
# Processing Record 8 of Set 7 | east ballina
# Processing Record 9 of Set 7 | gamba
# Processing Record 10 of Set 7 | flagstaff
# Processing Record 11 of Set 7 | dadukou
# Processing Record 12 of Set 7 | seryshevo
# Processing Record 13 of Set 7 | cidreira
# Processing Record 14 of Set 7 | margate
# Processing Record 15 of Set 7 | seogwipo
# City not found. Skipping...
# Processing Record 16 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 17 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 7 | khilok
# Processing Record 19 of Set 7 | jilib
# Processing Record 20 of Set 7 | inari
# Processing Record 21 of Set 7 | nizao
# Processing Record 22 of Set 7 | maragogi
# Processing Record 23 of Set 7 | urengoy
# Processing Record 24 of Set 7 | ta`u
# Processing Record 25 of Set 7 | yerofey pavlovich
# Processing Record 26 of Set 7 | kavieng
# Processing Record 27 of Set 7 | guariba
# Processing Record 28 of Set 7 | howrah
# Processing Record 29 of Set 7 | mbuji-mayi
# Processing Record 30 of Set 7 | pauini
# Processing Record 31 of Set 7 | nogamerzin-yurt
# Processing Record 32 of Set 7 | lame
# Processing Record 33 of Set 7 | okha
# Processing Record 34 of Set 7 | inhambane
# Processing Record 35 of Set 7 | el calafate
# Processing Record 36 of Set 7 | polyarnyy
# Processing Record 37 of Set 7 | jwaneng
# Processing Record 38 of Set 7 | mlangali
# Processing Record 39 of Set 7 | aswan
# Processing Record 40 of Set 7 | paracuru
# Processing Record 41 of Set 7 | al fuwayliq
# Processing Record 42 of Set 7 | pandan
# Processing Record 43 of Set 7 | remire-montjoly
# Processing Record 44 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 45 of Set 7 | kayangel
# Processing Record 46 of Set 7 | ulsteinvik
# Processing Record 47 of Set 7 | port pirie
# Processing Record 48 of Set 7 | shubarkuduk
# Processing Record 49 of Set 7 | jose pedro varela
# Processing Record 50 of Set 7 | tateyama
# Processing Record 1 of Set 8 | port macquarie
# Processing Record 2 of Set 8 | coquimbo
# Processing Record 3 of Set 8 | quiruvilca
# Processing Record 4 of Set 8 | general pinedo
# Processing Record 5 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 6 of Set 8 | abepura
# Processing Record 7 of Set 8 | bokhan
# Processing Record 8 of Set 8 | opuwo
# Processing Record 9 of Set 8 | aleksandrovsk-sakhalinskiy
# Processing Record 10 of Set 8 | queenstown
# Processing Record 11 of Set 8 | nemuro
# Processing Record 12 of Set 8 | praia da vitoria
# Processing Record 13 of Set 8 | konarka
# Processing Record 14 of Set 8 | tvoroyri
# Processing Record 15 of Set 8 | anapa
# Processing Record 16 of Set 8 | las heras
# Processing Record 17 of Set 8 | papao
# Processing Record 18 of Set 8 | murzuq
# Processing Record 19 of Set 8 | phanom thuan
# Processing Record 20 of Set 8 | lichuan
# Processing Record 21 of Set 8 | kitaibaraki
# Processing Record 22 of Set 8 | zaozersk
# Processing Record 23 of Set 8 | bani walid
# Processing Record 24 of Set 8 | oriximina
# Processing Record 25 of Set 8 | ashburton
# Processing Record 26 of Set 8 | ad dabbah
# Processing Record 27 of Set 8 | yanykurgan
# Processing Record 28 of Set 8 | paita
# Processing Record 29 of Set 8 | puerto baquerizo moreno
# Processing Record 30 of Set 8 | petukhovo
# Processing Record 31 of Set 8 | christchurch
# Processing Record 32 of Set 8 | bria
# Processing Record 33 of Set 8 | kichmengskiy gorodok
# Processing Record 34 of Set 8 | nantucket
# Processing Record 35 of Set 8 | plettenberg bay
# Processing Record 36 of Set 8 | karratha
# Processing Record 37 of Set 8 | vannes
# Processing Record 38 of Set 8 | kirensk
# Processing Record 39 of Set 8 | broome
# Processing Record 40 of Set 8 | tecate
# Processing Record 41 of Set 8 | tame
# Processing Record 42 of Set 8 | constitucion
# Processing Record 43 of Set 8 | lock haven
# Processing Record 44 of Set 8 | bobrov
# Processing Record 45 of Set 8 | tripoli
# Processing Record 46 of Set 8 | myanaung
# Processing Record 47 of Set 8 | flying fish cove
# Processing Record 48 of Set 8 | dettelbach
# Processing Record 49 of Set 8 | labuan
# Processing Record 50 of Set 8 | irymple
# Processing Record 1 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 2 of Set 9 | pijijiapan
# Processing Record 3 of Set 9 | carlinville
# Processing Record 4 of Set 9 | hilo
# Processing Record 5 of Set 9 | korla
# Processing Record 6 of Set 9 | mariehamn
# Processing Record 7 of Set 9 | darnah
# Processing Record 8 of Set 9 | vorgashor
# Processing Record 9 of Set 9 | at taj
# Processing Record 10 of Set 9 | atakpame
# Processing Record 11 of Set 9 | howard springs
# Processing Record 12 of Set 9 | pacific grove
# Processing Record 13 of Set 9 | silver city
# Processing Record 14 of Set 9 | sainte-menehould
# Processing Record 15 of Set 9 | isangel
# Processing Record 16 of Set 9 | huarmey
# Processing Record 17 of Set 9 | sechura
# Processing Record 18 of Set 9 | sao raimundo das mangabeiras
# Processing Record 19 of Set 9 | marka
# Processing Record 20 of Set 9 | inarajan village
# Processing Record 21 of Set 9 | natal
# Processing Record 22 of Set 9 | kristiansund
# Processing Record 23 of Set 9 | akureyri
# Processing Record 24 of Set 9 | cabugao
# Processing Record 25 of Set 9 | manokwari
# Processing Record 26 of Set 9 | nanao
# Processing Record 27 of Set 9 | arteche
# Processing Record 28 of Set 9 | buabidi
# City not found. Skipping...
# Processing Record 29 of Set 9 | natchez
# Processing Record 30 of Set 9 | kampong chhnang
# Processing Record 31 of Set 9 | mana
# Processing Record 32 of Set 9 | yaren
# Processing Record 33 of Set 9 | cestos city
# Processing Record 34 of Set 9 | hirara
# Processing Record 35 of Set 9 | nefteyugansk
# Processing Record 36 of Set 9 | dalandzadgad
# Processing Record 37 of Set 9 | moab
# Processing Record 38 of Set 9 | akarp
# Processing Record 39 of Set 9 | bagaha
# Processing Record 40 of Set 9 | gadzhiyevo
# Processing Record 41 of Set 9 | aztec
# Processing Record 42 of Set 9 | vadso
# Processing Record 43 of Set 9 | santana
# Processing Record 44 of Set 9 | lazaro cardenas
# Processing Record 45 of Set 9 | darwin
# Processing Record 46 of Set 9 | nijar
# Processing Record 47 of Set 9 | north shore
# Processing Record 48 of Set 9 | geispolsheim
# Processing Record 49 of Set 9 | charters towers
# Processing Record 50 of Set 9 | khabarovsk
# Processing Record 1 of Set 10 | nagqu
# Processing Record 2 of Set 10 | beatrice
# Processing Record 3 of Set 10 | kletskaya
# Processing Record 4 of Set 10 | bathsheba
# Processing Record 5 of Set 10 | raichur
# Processing Record 6 of Set 10 | conde
# Processing Record 7 of Set 10 | puerto santa
# Processing Record 8 of Set 10 | zuera
# Processing Record 9 of Set 10 | coeur d'alene
# Processing Record 10 of Set 10 | karachi
# Processing Record 11 of Set 10 | claveria
# Processing Record 12 of Set 10 | qingdao
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | poggiardo
# Processing Record 15 of Set 10 | gbarnga
# Processing Record 16 of Set 10 | saint-philippe
# Processing Record 17 of Set 10 | sidi ifni
# Processing Record 18 of Set 10 | stephenville
# Processing Record 19 of Set 10 | salqin
# Processing Record 20 of Set 10 | novaya igirma
# Processing Record 21 of Set 10 | vermillion
# Processing Record 22 of Set 10 | nyurba
# Processing Record 23 of Set 10 | gandajika
# Processing Record 24 of Set 10 | arcoverde
# Processing Record 25 of Set 10 | chonchi
# Processing Record 26 of Set 10 | severo-yeniseyskiy
# Processing Record 27 of Set 10 | parang
# Processing Record 28 of Set 10 | todmorden
# Processing Record 29 of Set 10 | fort st. john
# Processing Record 30 of Set 10 | mahina
# Processing Record 31 of Set 10 | lihue
# Processing Record 32 of Set 10 | zemio
# Processing Record 33 of Set 10 | umarkot
# Processing Record 34 of Set 10 | karema
# Processing Record 35 of Set 10 | argamasilla de calatrava
# Processing Record 36 of Set 10 | bamboo flat
# Processing Record 37 of Set 10 | hammerfest
# Processing Record 38 of Set 10 | coracao de jesus
# Processing Record 39 of Set 10 | vallenar
# Processing Record 40 of Set 10 | ust'-ilimsk
# Processing Record 41 of Set 10 | baringo
# Processing Record 42 of Set 10 | matthew town
# Processing Record 43 of Set 10 | sidhi
# Processing Record 44 of Set 10 | malpica
# Processing Record 45 of Set 10 | waycross
# Processing Record 46 of Set 10 | tomatlan
# Processing Record 47 of Set 10 | evinayong
# Processing Record 48 of Set 10 | kassala
# Processing Record 49 of Set 10 | neiafu
# Processing Record 50 of Set 10 | horta
# Processing Record 1 of Set 11 | chinde
# Processing Record 2 of Set 11 | port saint john's
# Processing Record 3 of Set 11 | zarghun shahr
# Processing Record 4 of Set 11 | kununurra
# Processing Record 5 of Set 11 | ukiah
# Processing Record 6 of Set 11 | ierapetra
# Processing Record 7 of Set 11 | moussoro
# Processing Record 8 of Set 11 | melekeok village
# Processing Record 9 of Set 11 | bom jesus
# Processing Record 10 of Set 11 | cabedelo
# Processing Record 11 of Set 11 | cat ba
# City not found. Skipping...
# Processing Record 12 of Set 11 | bulgan
# Processing Record 13 of Set 11 | zhangye
# Processing Record 14 of Set 11 | baruun-urt
# Processing Record 15 of Set 11 | cabcaben
# Processing Record 16 of Set 11 | tonj
# Processing Record 17 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 18 of Set 11 | flin flon
# Processing Record 19 of Set 11 | plastun
# Processing Record 20 of Set 11 | tacuarembo
# Processing Record 21 of Set 11 | popesti
# Processing Record 22 of Set 11 | amga
# Processing Record 23 of Set 11 | mount isa
# Processing Record 24 of Set 11 | massawa
# Processing Record 25 of Set 11 | salem
# Processing Record 26 of Set 11 | ambon
# Processing Record 27 of Set 11 | maposeni
# Processing Record 28 of Set 11 | cambria
# Processing Record 29 of Set 11 | linxia chengguanzhen
# Processing Record 30 of Set 11 | gisborne
# Processing Record 31 of Set 11 | shuangjiang
# Processing Record 32 of Set 11 | punta arenas
# Processing Record 33 of Set 11 | fort bragg
# Processing Record 34 of Set 11 | ust'-uda
# Processing Record 35 of Set 11 | berdigestyakh
# Processing Record 36 of Set 11 | tereze
# Processing Record 37 of Set 11 | mamuju
# Processing Record 38 of Set 11 | takaungu
# Processing Record 39 of Set 11 | palmer
# Processing Record 40 of Set 11 | antofagasta
# Processing Record 41 of Set 11 | bumba
# Processing Record 42 of Set 11 | namibe
# Processing Record 43 of Set 11 | phang nga
# Processing Record 44 of Set 11 | porto novo
# Processing Record 45 of Set 11 | al artawiyah
# Processing Record 46 of Set 11 | kyelang
# Processing Record 47 of Set 11 | ituango
# Processing Record 48 of Set 11 | san pedro pochutla
# Processing Record 49 of Set 11 | galashki
# Processing Record 50 of Set 11 | nago
# Processing Record 1 of Set 12 | minot
# Processing Record 2 of Set 12 | guatrache
# Processing Record 3 of Set 12 | belvedere marittimo
# Processing Record 4 of Set 12 | rongelap
# Processing Record 5 of Set 12 | kangding
# Processing Record 6 of Set 12 | lata
# Processing Record 7 of Set 12 | miandrivazo
# Processing Record 8 of Set 12 | aguachica
# Processing Record 9 of Set 12 | el porvenir
# Processing Record 10 of Set 12 | kayenta
# Processing Record 11 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 12 of Set 12 | el bauga
# Processing Record 13 of Set 12 | inirida
# Processing Record 14 of Set 12 | bichena
# Processing Record 15 of Set 12 | hanceville
# Processing Record 16 of Set 12 | martuk
# Processing Record 17 of Set 12 | qui nhon
# Processing Record 18 of Set 12 | mthatha
# Processing Record 19 of Set 12 | nieuw amsterdam
# Processing Record 20 of Set 12 | piton saint-leu
# Processing Record 21 of Set 12 | port shepstone
# Processing Record 22 of Set 12 | tczew
# Processing Record 23 of Set 12 | berezovyy
# Processing Record 24 of Set 12 | kapuskasing
# Processing Record 25 of Set 12 | khash
# Processing Record 26 of Set 12 | baotou
# Processing Record 27 of Set 12 | sweetwater
# Processing Record 28 of Set 12 | halifax
# Processing Record 29 of Set 12 | tauranga
# Processing Record 30 of Set 12 | acarau
# Processing Record 31 of Set 12 | hoi an
# Processing Record 32 of Set 12 | gebeit
# Processing Record 33 of Set 12 | otjimbingwe
# Processing Record 34 of Set 12 | castillos
# Processing Record 35 of Set 12 | celestun
# Processing Record 36 of Set 12 | myers corner
# Processing Record 37 of Set 12 | roma
# Processing Record 38 of Set 12 | idri
# Processing Record 39 of Set 12 | cantilan
# Processing Record 40 of Set 12 | chanthaburi
# Processing Record 41 of Set 12 | whitecourt
# Processing Record 42 of Set 12 | ropazi
# Processing Record 43 of Set 12 | selfoss
# Processing Record 44 of Set 12 | lagunas
# Processing Record 45 of Set 12 | vega alta
# Processing Record 46 of Set 12 | vernon
# Processing Record 47 of Set 12 | keokuk
# Processing Record 48 of Set 12 | vila do maio
# Processing Record 49 of Set 12 | espargos
# City not found. Skipping...
# Processing Record 50 of Set 12 | fuxin
# Processing Record 1 of Set 13 | karukh
# Processing Record 2 of Set 13 | whangarei
# Processing Record 3 of Set 13 | aral
# Processing Record 4 of Set 13 | kroya
# Processing Record 5 of Set 13 | rouissat
# Processing Record 6 of Set 13 | kalat
# Processing Record 7 of Set 13 | kyren
# Processing Record 8 of Set 13 | santarem
# Processing Record 9 of Set 13 | gantang
# Processing Record 10 of Set 13 | holualoa
# Processing Record 11 of Set 13 | bhabhua
# Processing Record 12 of Set 13 | angaur state
# Processing Record 13 of Set 13 | lerwick
# Processing Record 14 of Set 13 | dame-marie
# Processing Record 15 of Set 13 | tres lagoas
# Processing Record 16 of Set 13 | sinan
# Processing Record 17 of Set 13 | andrews
# Processing Record 18 of Set 13 | keetmanshoop
# Processing Record 19 of Set 13 | condoto
# Processing Record 20 of Set 13 | hutchinson
# Processing Record 21 of Set 13 | airdrie
# Processing Record 22 of Set 13 | santa cruz
# Processing Record 23 of Set 13 | saint-pierre
# Processing Record 24 of Set 13 | outokumpu
# Processing Record 25 of Set 13 | poltavka
# Processing Record 26 of Set 13 | norrtalje
# Processing Record 27 of Set 13 | kinablangan
# Processing Record 28 of Set 13 | sokhumi
# Processing Record 29 of Set 13 | tavda
# Processing Record 30 of Set 13 | seymour
# Processing Record 31 of Set 13 | acajutla
# Processing Record 32 of Set 13 | kafanchan
# Processing Record 33 of Set 13 | omaruru
# Processing Record 34 of Set 13 | lemvig
# Processing Record 35 of Set 13 | nova sintra
# Processing Record 36 of Set 13 | koulamoutou
# Processing Record 37 of Set 13 | mokhotlong
# Processing Record 38 of Set 13 | kismayo
# Processing Record 39 of Set 13 | pokhara
# Processing Record 40 of Set 13 | penzance
# Processing Record 41 of Set 13 | yantzaza
# Processing Record 42 of Set 13 | tarnogskiy gorodok
# Processing Record 43 of Set 13 | pionerskiy
# Processing Record 44 of Set 13 | gurupa
# Processing Record 45 of Set 13 | banjarmasin
# Processing Record 46 of Set 13 | kitob
# Processing Record 47 of Set 13 | tynda
# Processing Record 48 of Set 13 | yazd
# Processing Record 49 of Set 13 | terme
# Processing Record 50 of Set 13 | redencao
# Processing Record 1 of Set 14 | armstrong
# Processing Record 2 of Set 14 | kailua-kona
# Processing Record 3 of Set 14 | copala
# Processing Record 4 of Set 14 | boguchany
# Processing Record 5 of Set 14 | kualakapuas
# Processing Record 6 of Set 14 | tejen
# Processing Record 7 of Set 14 | west fargo
# Processing Record 8 of Set 14 | bhind
# Processing Record 9 of Set 14 | san juan nepomuceno
# Processing Record 10 of Set 14 | kendari
# Processing Record 11 of Set 14 | kawerau
# Processing Record 12 of Set 14 | naze
# Processing Record 13 of Set 14 | makanya
# Processing Record 14 of Set 14 | dudinka
# Processing Record 15 of Set 14 | 'izbat al burj
# City not found. Skipping...
# Processing Record 16 of Set 14 | bairnsdale
# Processing Record 17 of Set 14 | inekar
# City not found. Skipping...
# Processing Record 18 of Set 14 | kolonia town
# Processing Record 19 of Set 14 | ventanas
# Processing Record 20 of Set 14 | palembang
# Processing Record 21 of Set 14 | nizhnesortymskiy
# Processing Record 22 of Set 14 | fortuna foothills
# Processing Record 23 of Set 14 | port sudan
# Processing Record 24 of Set 14 | kwaksan
# Processing Record 25 of Set 14 | pasuquin
# Processing Record 26 of Set 14 | n'zeto
# Processing Record 27 of Set 14 | rampur
# Processing Record 28 of Set 14 | mulayjah
# Processing Record 29 of Set 14 | soure
# Processing Record 30 of Set 14 | muli
# Processing Record 31 of Set 14 | sabang
# Processing Record 32 of Set 14 | coahuayana de hidalgo
# Processing Record 33 of Set 14 | nova vicosa
# Processing Record 34 of Set 14 | fomboni
# Processing Record 35 of Set 14 | hailar
# Processing Record 36 of Set 14 | ugoofaaru
# Processing Record 37 of Set 14 | al kharijah
# Processing Record 38 of Set 14 | pasargad
# City not found. Skipping...
# Processing Record 39 of Set 14 | awjilah
# Processing Record 40 of Set 14 | mejit
# Processing Record 41 of Set 14 | mahajanga
# Processing Record 42 of Set 14 | rabo de peixe
# Processing Record 43 of Set 14 | arno
# Processing Record 44 of Set 14 | longgang
# Processing Record 45 of Set 14 | road town
# Processing Record 46 of Set 14 | tamanrasset
# Processing Record 47 of Set 14 | katsuren-haebaru
# Processing Record 48 of Set 14 | tofol
# Processing Record 49 of Set 14 | borogontsy
# Processing Record 50 of Set 14 | san juan bautista
# Processing Record 1 of Set 15 | i-n-salah
# Processing Record 2 of Set 15 | fonadhoo
# City not found. Skipping...
# Processing Record 3 of Set 15 | mount carmel
# Processing Record 4 of Set 15 | lesnoy
# Processing Record 5 of Set 15 | maloye ganyushkino
# Processing Record 6 of Set 15 | taksimo
# Processing Record 7 of Set 15 | enchanted hills
# Processing Record 8 of Set 15 | takoradi
# Processing Record 9 of Set 15 | jelcz
# Processing Record 10 of Set 15 | balabac
# Processing Record 11 of Set 15 | yeppoon
# Processing Record 12 of Set 15 | whistler
# Processing Record 13 of Set 15 | kurumkan
# Processing Record 14 of Set 15 | bubaque
# Processing Record 15 of Set 15 | bada
# Processing Record 16 of Set 15 | balqash
# Processing Record 17 of Set 15 | ostuni
# Processing Record 18 of Set 15 | maffra
# Processing Record 19 of Set 15 | whitby
# Processing Record 20 of Set 15 | oyama
# Processing Record 21 of Set 15 | khandyga
# Processing Record 22 of Set 15 | pustoshka
# Processing Record 23 of Set 15 | puerto aysen
# Processing Record 24 of Set 15 | glennville
# Processing Record 25 of Set 15 | kapoeta
# Processing Record 26 of Set 15 | melenci
# Processing Record 27 of Set 15 | scarborough
# Processing Record 28 of Set 15 | basco
# Processing Record 29 of Set 15 | zheshart
# Processing Record 30 of Set 15 | kalemie
# Processing Record 31 of Set 15 | sittwe
# Processing Record 32 of Set 15 | korotchaevo
# City not found. Skipping...
# Processing Record 33 of Set 15 | mbanza kongo
# Processing Record 34 of Set 15 | dompu
# Processing Record 35 of Set 15 | luanda
# Processing Record 36 of Set 15 | cuamba
# Processing Record 37 of Set 15 | revelstoke
# Processing Record 38 of Set 15 | danghara
# Processing Record 39 of Set 15 | fazendas de almeirim
# Processing Record 40 of Set 15 | cananeia
# Processing Record 41 of Set 15 | lianjiang
# Processing Record 42 of Set 15 | keflavik
# Processing Record 43 of Set 15 | muzayri'
# City not found. Skipping...
# Processing Record 44 of Set 15 | turpan
# Processing Record 45 of Set 15 | cole harbour
# Processing Record 46 of Set 15 | sirpur
# Processing Record 47 of Set 15 | sharlyk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 719

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                           City Country      Lat       Lng  Max Temp  Humidity  \
# 0                      taulaga      AS -11.0553 -171.0883     83.62        76
# 1  edinburgh of the seven seas      SH -37.0676  -12.3116     61.38        80
# 2                       uturoa      PF -16.7333 -151.4333     82.53        78
# 3                   isafjordur      IS  66.0755  -23.1240     32.74        78
# 4                      quellon      CL -43.1167  -73.6167     37.65       100
# 5                     smithers      CA  54.7804 -127.1743     48.52        61
# 6                       albany      US  42.6001  -73.9662     46.58        86
# 7                      forster      AU -32.1667  152.5167     66.15        61
# 8                    adamstown      PN -25.0660 -130.1015     77.31        79
# 9                        sursk      RU  53.0754   45.6846     56.16        64
#
#    Cloudiness  Wind Speed Current Description
# 0          14       17.02          light rain
# 1          13       22.41          few clouds
# 2         100       17.58          light rain
# 3          52        5.48       broken clouds
# 4          40        0.00    scattered clouds
# 5           0        3.44           clear sky
# 6         100        1.01          light rain
# 7          43        1.99    scattered clouds
# 8          28       17.09    scattered clouds
# 9          92        5.30     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#                           City Country      Lat       Lng  Max Temp  Humidity  \
# 0                      taulaga      AS -11.0553 -171.0883     83.62        76
# 1  edinburgh of the seven seas      SH -37.0676  -12.3116     61.38        80
# 2                       uturoa      PF -16.7333 -151.4333     82.53        78
# 3                   isafjordur      IS  66.0755  -23.1240     32.74        78
# 4                      quellon      CL -43.1167  -73.6167     37.65       100
#
#    Cloudiness  Wind Speed Current Description
# 0          14       17.02          light rain
# 1          13       22.41          few clouds
# 2         100       17.58          light rain
# 3          52        5.48       broken clouds
# 4          40        0.00    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label="City_ID")
